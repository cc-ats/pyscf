# %%
# %run test_resonant_water.py
# Out:
# Initializing Propagator: <class 'pyscf.rt.propagator.MMUTPropogator'>
#
#
# ******** <class 'pyscf.rt.rks.TDDFT'> ********
# This is a Real-Time TDDFT calculation initialized with a converged RKS instance
# The SCF converged tolerence is conv_tol = 1e-12
# xc = pbe0
# step_size = 0.200000, total_step = 4000
# prop_obj = <class 'pyscf.rt.propagator.MMUTPropogator'>
# max_memory 4000 MB (current use 0 MB)
#     The results would be saved in the disk, h2o_z_1.00e-02.chk.
#     4001 out of 4001 steps are saved in the memory.
#     4001 out of 4001 steps are saved in the disk.
# after propogation matrices, max_memory 4000 MB (current use 0 MB)
# Propagation finished
# Reading              t from h2o_z_1.00e-02.chk.
# Reading         dipole from h2o_z_1.00e-02.chk.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/pyscf/pyscf/rt/test/test_resonant_water.py in <module>
# ...
